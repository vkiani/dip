# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('house.tif', cv.IMREAD_GRAYSCALE)

if img is None:
    raise Exception("Image not loaded!")
   
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7FF0A5D850>
