# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('medical.png', cv.IMREAD_GRAYSCALE)

kernel = np.ones((5,5), np.uint8)

top_hat = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
black_hat = cv.morphologyEx(img, cv.MORPH_BLACKHAT, kernel)

res = img + top_hat - black_hat

plt.subplot(1,2,1), plt.imshow(img, cmap='gray')
plt.xticks([]), plt.yticks([])

plt.subplot(1,2,2), plt.imshow(res, cmap='gray')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))
